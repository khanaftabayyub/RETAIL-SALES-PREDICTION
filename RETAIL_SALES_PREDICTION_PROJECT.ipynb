# %%
# ===============================================================
# RETAIL SALES PREDICTION PROJECT
# Part 1 - Data Loading, Cleaning & Exploration
# ===============================================================

# Install required libraries (Run only once)
# !pip install openpyxl -q

# ===============================================================
# Import Libraries
# ===============================================================

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from google.colab import files

sns.set_style("whitegrid")
plt.rcParams["figure.figsize"]=(10,6)

pd.set_option("display.max_columns",None)

print("="*70)
print("      RETAIL SALES PREDICTION PROJECT")
print("="*70)

# ===============================================================
# Upload Dataset
# ===============================================================

print("\nUpload SampleSuperstore.csv\n")

uploaded = files.upload()

filename = list(uploaded.keys())[0]

print("Uploaded File :",filename)

# ===============================================================
# Load Dataset
# ===============================================================

df = pd.read_csv(filename)

print("\nDataset Loaded Successfully")

# ===============================================================
# First Rows
# ===============================================================

print("\nFirst 5 Rows")

display(df.head())

# ===============================================================
# Last Rows
# ===============================================================

print("\nLast 5 Rows")

display(df.tail())

# ===============================================================
# Shape
# ===============================================================

print("\nDataset Shape")

print("Rows :",df.shape[0])
print("Columns :",df.shape[1])

# ===============================================================
# Columns
# ===============================================================

print("\nColumn Names")

for col in df.columns:
    print(col)

# ===============================================================
# Dataset Information
# ===============================================================

print("\nDataset Information")

df.info()

# ===============================================================
# Data Types
# ===============================================================

print("\nData Types")

display(df.dtypes)

# ===============================================================
# Statistical Summary
# ===============================================================

print("\nStatistical Summary")

display(df.describe())

print("\nComplete Summary")

display(df.describe(include="all"))

# ===============================================================
# Missing Values
# ===============================================================

print("\nMissing Values")

missing = df.isnull().sum()

missing_percent = round((missing/len(df))*100,2)

missing_table = pd.DataFrame({

    "Missing Values":missing,

    "Percentage":missing_percent

})

display(missing_table)

# ===============================================================
# Missing Value Heatmap
# ===============================================================

plt.figure(figsize=(12,6))

sns.heatmap(df.isnull(),

            cbar=False,

            cmap="viridis")

plt.title("Missing Values Heatmap")

plt.show()

# ===============================================================
# Duplicate Records
# ===============================================================

duplicates=df.duplicated().sum()

print("\nDuplicate Rows :",duplicates)

if duplicates>0:

    df=df.drop_duplicates()

    print("Duplicate Rows Removed")

else:

    print("No Duplicate Rows Found")

# ===============================================================
# Unique Values
# ===============================================================

print("\nUnique Values")

for col in df.columns:

    print(col,"=",df[col].nunique())

# ===============================================================
# Convert Date Columns
# ===============================================================

if "Order Date" in df.columns:

    df["Order Date"]=pd.to_datetime(df["Order Date"])

if "Ship Date" in df.columns:

    df["Ship Date"]=pd.to_datetime(df["Ship Date"])

print("\nDate Conversion Completed")

# ===============================================================
# Feature Engineering
# ===============================================================

if "Order Date" in df.columns:

    df["Year"]=df["Order Date"].dt.year

    df["Month"]=df["Order Date"].dt.month_name()

    df["Day"]=df["Order Date"].dt.day

print("\nNew Features Added")

# ===============================================================
# Correlation
# ===============================================================

numeric=df.select_dtypes(include=np.number)

print("\nCorrelation Matrix")

display(numeric.corr())

plt.figure(figsize=(10,8))

sns.heatmap(

    numeric.corr(),

    annot=True,

    cmap="coolwarm",

    fmt=".2f"

)

plt.title("Correlation Heatmap")

plt.show()

# ===============================================================
# Save Clean Dataset
# ===============================================================

df.to_csv("Retail_Cleaned.csv",index=False)

print("\nClean Dataset Saved Successfully")

print("="*70)
print("Part 1 Completed Successfully")
print("="*70)
# Out:
# ...
#       RETAIL SALES PREDICTION PROJECT
# ...
#
# Upload SampleSuperstore.csv
#      <input type="file" id="files-2463e5a3-a958-4ffa-8a87-caaa76118d63" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2463e5a3-a958-4ffa-8a87-caaa76118d63">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
# ===============================================================
# RETAIL SALES PREDICTION PROJECT
# Part 2 - Exploratory Data Analysis & Visualizations
# ===============================================================

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

print("="*70)
print("PART 2 - EXPLORATORY DATA ANALYSIS")
print("="*70)

# ===============================================================
# Sales Distribution
# ===============================================================

plt.figure(figsize=(8,5))
sns.histplot(df["Sales"], bins=30, kde=True, color="blue")
plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# ===============================================================
# Profit Distribution
# ===============================================================

plt.figure(figsize=(8,5))
sns.histplot(df["Profit"], bins=30, kde=True, color="green")
plt.title("Profit Distribution")
plt.xlabel("Profit")
plt.ylabel("Frequency")
plt.show()

# ===============================================================
# Sales Boxplot
# ===============================================================

plt.figure(figsize=(8,5))
sns.boxplot(y=df["Sales"], color="orange")
plt.title("Sales Boxplot")
plt.show()

# ===============================================================
# Profit Boxplot
# ===============================================================

plt.figure(figsize=(8,5))
sns.boxplot(y=df["Profit"], color="red")
plt.title("Profit Boxplot")
plt.show()

# ===============================================================
# Category Count
# ===============================================================

plt.figure(figsize=(8,5))
sns.countplot(data=df, x="Category")
plt.title("Products by Category")
plt.show()

# ===============================================================
# Sales by Category
# ===============================================================

plt.figure(figsize=(8,5))

sales_category = df.groupby("Category")["Sales"].sum().reset_index()

sns.barplot(data=sales_category,
            x="Category",
            y="Sales")

plt.title("Total Sales by Category")
plt.show()

# ===============================================================
# Profit by Category
# ===============================================================

plt.figure(figsize=(8,5))

profit_category = df.groupby("Category")["Profit"].sum().reset_index()

sns.barplot(data=profit_category,
            x="Category",
            y="Profit")

plt.title("Total Profit by Category")
plt.show()

# ===============================================================
# Sales by Region
# ===============================================================

plt.figure(figsize=(8,5))

sales_region = df.groupby("Region")["Sales"].sum().reset_index()

sns.barplot(data=sales_region,
            x="Region",
            y="Sales")

plt.title("Sales by Region")
plt.show()

# ===============================================================
# Profit by Region
# ===============================================================

plt.figure(figsize=(8,5))

profit_region = df.groupby("Region")["Profit"].sum().reset_index()

sns.barplot(data=profit_region,
            x="Region",
            y="Profit")

plt.title("Profit by Region")
plt.show()

# ===============================================================
# Sales by Segment
# ===============================================================

plt.figure(figsize=(8,5))

segment_sales = df.groupby("Segment")["Sales"].sum().reset_index()

sns.barplot(data=segment_sales,
            x="Segment",
            y="Sales")

plt.title("Sales by Customer Segment")
plt.show()

# ===============================================================
# Ship Mode Count
# ===============================================================

plt.figure(figsize=(8,5))
sns.countplot(data=df, x="Ship Mode")
plt.title("Ship Mode Distribution")
plt.xticks(rotation=20)
plt.show()

# ===============================================================
# Monthly Sales Trend
# ===============================================================

monthly_sales = df.groupby("Month")["Sales"].sum()

month_order = [
    "January","February","March","April","May","June",
    "July","August","September","October","November","December"
]

monthly_sales = monthly_sales.reindex(month_order)

plt.figure(figsize=(12,5))

monthly_sales.plot(marker="o")

plt.title("Monthly Sales Trend")

plt.ylabel("Sales")

plt.grid(True)

plt.show()

# ===============================================================
# Top 10 Products
# ===============================================================

top_products = df.groupby("Product Name")["Sales"].sum()

top_products = top_products.sort_values(ascending=False).head(10)

plt.figure(figsize=(12,6))

top_products.plot(kind="bar")

plt.title("Top 10 Products by Sales")

plt.ylabel("Sales")

plt.xticks(rotation=60)

plt.show()

# ===============================================================
# Discount Distribution
# ===============================================================

plt.figure(figsize=(7,5))
sns.countplot(data=df, x="Discount")
plt.title("Discount Distribution")
plt.show()

# ===============================================================
# Quantity Distribution
# ===============================================================

plt.figure(figsize=(7,5))
sns.histplot(df["Quantity"], bins=10)
plt.title("Quantity Distribution")
plt.show()

# ===============================================================
# Pie Chart - Category
# ===============================================================

category = df["Category"].value_counts()

plt.figure(figsize=(7,7))

plt.pie(category,
        labels=category.index,
        autopct="%1.1f%%",
        startangle=90)

plt.title("Category Percentage")

plt.show()

# ===============================================================
# Numerical Columns Histogram
# ===============================================================

df.hist(figsize=(14,10), bins=20)

plt.tight_layout()

plt.show()

print("="*70)
print("Part 2 Completed Successfully")
print("="*70)
# Out:
# ...
# PART 2 - EXPLORATORY DATA ANALYSIS
# ...
# Part 2 Completed Successfully
# ...

# %%
# ===============================================================
# RETAIL SALES PREDICTION PROJECT
# Part 3 - Correlation Analysis & Feature Engineering
# ===============================================================

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("="*70)
print("PART 3 - CORRELATION ANALYSIS & FEATURE ENGINEERING")
print("="*70)

# ===============================================================
# Correlation Matrix
# ===============================================================

numeric_df = df.select_dtypes(include=["number"])

plt.figure(figsize=(10,8))

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")
plt.show()

# ===============================================================
# Sales vs Profit
# ===============================================================

plt.figure(figsize=(8,6))

sns.scatterplot(
    data=df,
    x="Sales",
    y="Profit",
    hue="Category"
)

plt.title("Sales vs Profit")
plt.show()

# ===============================================================
# Discount vs Profit
# ===============================================================

plt.figure(figsize=(8,6))

sns.scatterplot(
    data=df,
    x="Discount",
    y="Profit",
    hue="Category"
)

plt.title("Discount vs Profit")
plt.show()

# ===============================================================
# Quantity vs Sales
# ===============================================================

plt.figure(figsize=(8,6))

sns.scatterplot(
    data=df,
    x="Quantity",
    y="Sales",
    hue="Segment"
)

plt.title("Quantity vs Sales")
plt.show()

# ===============================================================
# Pair Plot
# ===============================================================

sns.pairplot(
    df[["Sales","Profit","Quantity","Discount"]],
    diag_kind="hist"
)

plt.show()

# ===============================================================
# Average Sales by Region
# ===============================================================

print("\nAverage Sales by Region")

display(df.groupby("Region")["Sales"].mean())

# ===============================================================
# Average Profit by Region
# ===============================================================

print("\nAverage Profit by Region")

display(df.groupby("Region")["Profit"].mean())

# ===============================================================
# Average Sales by Category
# ===============================================================

print("\nAverage Sales by Category")

display(df.groupby("Category")["Sales"].mean())

# ===============================================================
# Average Profit by Category
# ===============================================================

print("\nAverage Profit by Category")

display(df.groupby("Category")["Profit"].mean())

# ===============================================================
# Top 10 Customers by Sales
# ===============================================================

top_customers = df.groupby("Customer Name")["Sales"].sum()

top_customers = top_customers.sort_values(ascending=False).head(10)

print("\nTop 10 Customers")

display(top_customers)

# ===============================================================
# Top 10 States by Sales
# ===============================================================

top_states = df.groupby("State")["Sales"].sum().sort_values(ascending=False)

plt.figure(figsize=(10,5))

sns.barplot(
    x=top_states.index,
    y=top_states.values
)

plt.title("Sales by State")

plt.xticks(rotation=45)

plt.show()

# ===============================================================
# Feature Engineering
# ===============================================================

# Profit Margin

df["Profit Margin (%)"] = round((df["Profit"]/df["Sales"])*100,2)

# High Discount

df["High Discount"] = df["Discount"].apply(
    lambda x: "Yes" if x >= 0.2 else "No"
)

print("\nNew Features Added Successfully!")

display(df.head())

# ===============================================================
# Profit Margin Distribution
# ===============================================================

plt.figure(figsize=(8,5))

sns.histplot(df["Profit Margin (%)"], bins=25, kde=True)

plt.title("Profit Margin Distribution")

plt.show()

# ===============================================================
# High Discount Analysis
# ===============================================================

plt.figure(figsize=(6,5))

sns.countplot(data=df, x="High Discount")

plt.title("High Discount Orders")

plt.show()

# ===============================================================
# Business Insights
# ===============================================================

print("\n" + "="*70)
print("BUSINESS INSIGHTS")
print("="*70)

print("""
1. Sales and Profit show a positive relationship.

2. Higher discounts generally reduce profit.

3. Technology products usually generate higher revenue.

4. Some regions contribute more to total sales than others.

5. Customers purchasing higher quantities tend to generate more sales.

6. Profit Margin helps identify highly profitable products.

7. High Discount orders should be monitored to avoid losses.
""")

print("="*70)
print("Part 3 Completed Successfully")
print("="*70)
# Out:
# ...
# PART 3 - CORRELATION ANALYSIS & FEATURE ENGINEERING
# ...
# Average Sales by Region
# Region
# Central    494.672598
# East       499.823554
# South      512.351836
# West       535.249315
# Name: Sales, dtype: float64
# Average Profit by Region
# Region
# Central    2.032992
# East       1.653554
# South      6.453086
# West       4.011210
# Name: Profit, dtype: float64
# Average Sales by Category
# Category
# Furniture          504.388459
# Office Supplies    530.881821
# Technology         496.965964
# Name: Sales, dtype: float64
# Average Profit by Category
# Category
# Furniture          4.821163
# Office Supplies    2.713673
# Technology         3.089157
# Name: Profit, dtype: float64
# Top 10 Customers
# Customer Name
# Customer 751    999.96
# Customer 19     999.30
# Customer 617    999.05
# Customer 653    998.84
# Customer 304    994.79
# Customer 623    993.79
# Customer 180    993.61
# Customer 461    992.87
# Customer 155    990.80
# Customer 730    987.16
# ...

# %%
# ===============================================================
# RETAIL SALES PREDICTION PROJECT
# Part 4 - Machine Learning Model
# ===============================================================

# Install sklearn
# !pip install -q scikit-learn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

print("="*70)
print("RETAIL SALES PREDICTION - MACHINE LEARNING")
print("="*70)

# ===============================================================
# Create Copy
# ===============================================================

model_df = df.copy()

# ===============================================================
# Remove Datetime Columns
# ===============================================================

date_columns = ["Order Date","Ship Date"]

for col in date_columns:
    if col in model_df.columns:
        model_df.drop(col,axis=1,inplace=True)

print("Datetime Columns Removed")

# ===============================================================
# Encode Categorical Columns
# ===============================================================

encoder = LabelEncoder()

for col in model_df.select_dtypes(include="object").columns:
    model_df[col] = encoder.fit_transform(model_df[col].astype(str))

print("Categorical Columns Encoded")

# ===============================================================
# Fill Missing Values
# ===============================================================

model_df = model_df.fillna(0)

# ===============================================================
# Features & Target
# ===============================================================

X = model_df.drop("Sales",axis=1)

y = model_df["Sales"]

print("\nFeature Shape :",X.shape)
print("Target Shape :",y.shape)

# ===============================================================
# Train Test Split
# ===============================================================

X_train,X_test,y_train,y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("\nTraining Samples :",len(X_train))
print("Testing Samples :",len(X_test))

# ===============================================================
# Build Model
# ===============================================================

model = LinearRegression()

model.fit(X_train,y_train)

print("\nModel Training Completed Successfully")

# ===============================================================
# Prediction
# ===============================================================

y_pred = model.predict(X_test)

# ===============================================================
# Evaluation
# ===============================================================

mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test,y_pred)

print("\n"+"="*60)
print("MODEL EVALUATION")
print("="*60)

print("MAE :",round(mae,2))
print("MSE :",round(mse,2))
print("RMSE :",round(rmse,2))
print("R2 Score :",round(r2,4))

# ===============================================================
# Actual vs Prediction
# ===============================================================

results = pd.DataFrame({
    "Actual Sales":y_test.values,
    "Predicted Sales":np.round(y_pred,2)
})

print("\nSample Predictions")

display(results.head(10))

# ===============================================================
# Scatter Plot
# ===============================================================

plt.figure(figsize=(8,6))

plt.scatter(y_test,y_pred)

plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")

plt.title("Actual vs Predicted Sales")

plt.grid(True)

plt.show()

# ===============================================================
# Prediction Line
# ===============================================================

plt.figure(figsize=(12,5))

plt.plot(y_test.values[:50],
         marker='o',
         label="Actual")

plt.plot(y_pred[:50],
         marker='*',
         label="Predicted")

plt.legend()

plt.title("Actual vs Predicted Sales")

plt.show()

# ===============================================================
# Feature Importance
# ===============================================================

importance = pd.DataFrame({

    "Feature":X.columns,

    "Coefficient":model.coef_

})

importance = importance.sort_values(
    by="Coefficient",
    ascending=False
)

print("\nTop 15 Important Features")

display(importance.head(15))

# ===============================================================
# Save Prediction
# ===============================================================

results.to_csv(
    "Sales_Predictions.csv",
    index=False
)

print("\nPrediction File Saved Successfully")

# ===============================================================
# Business Interpretation
# ===============================================================

print("\n"+"="*60)
print("BUSINESS INSIGHTS")
print("="*60)

print("""
1. The model predicts retail sales using historical transaction data.

2. Features with larger coefficients have a stronger influence on sales.

3. Profit and Quantity generally contribute positively to sales.

4. Discounts may reduce profitability even when sales increase.

5. The trained model can estimate future sales for new records.
""")

print("\n"+"="*70)
print("PART 4 COMPLETED SUCCESSFULLY")
print("="*70)
# Out:
# ...
# RETAIL SALES PREDICTION - MACHINE LEARNING
# ...
# Datetime Columns Removed
# Categorical Columns Encoded
#
# Feature Shape : (1000, 21)
# Target Shape : (1000,)
#
# Training Samples : 800
# Testing Samples : 200
#
# Model Training Completed Successfully
#
# ...
# MODEL EVALUATION
# ...
# MAE : 230.16
# MSE : 71794.73
# RMSE : 267.95
# R2 Score : 0.0328
#
# Sample Predictions
#    Actual Sales  Predicted Sales
# 0        551.59           486.46
# 1        651.11           445.32
# 2        329.61           501.87
# 3        648.15           496.38
# 4        663.74           540.33
# 5        205.32           462.48
# 6        671.70           511.63
# 7        481.57           543.24
# 8        935.43           463.59
# 9        455.06           512.15
# Top 15 Important Features
#           Feature   Coefficient
# 8          Region  1.246182e+01
# 16           Year  7.897338e+00
# 1       Ship Mode  2.723932e+00
# 18            Day  1.685011e+00
# 15         Profit  1.641892e+00
# ...
